# %% [markdown]
# # **GPA Predictor using Linear regression**
# Can GPA be actually predicted through small habits like weekly study hours, sleep hours, workout hours and which seat row you choose? In this mini project I'm implementing a linear regression to find this out.
#
# The data was collected through Google form among freshmen and sophomores Inha Students.
# Google sheets with data collected: https://docs.google.com/spreadsheets/d/1Jr0uiEkliaXU0cRTHi70fs4pq5OwMI66fOK1fUDShOc/edit?usp=sharing
#
# The Gooogle form:

# %% [markdown]
# ![image.png](attachment:d13db3ef-7568-4284-9473-934f342c148e.png)
# ![image.png](attachment:5f24946c-099c-4025-a82f-9d489082b78f.png)
# ![image.png](attachment:2d34c996-9b54-44fd-a47f-7db7cfcb6251.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Preparing data:

# %%
url = "https://docs.google.com/spreadsheets/d/1Jr0uiEkliaXU0cRTHi70fs4pq5OwMI66fOK1fUDShOc/export?format=csv"
df = pd.read_csv(url)
df.columns = ['timestamp', 'target', 'study','sleep','seat','workout']
target = df['target']
x = df.drop(columns=['timestamp', 'target'])
# Out:
# [0. 0. 0. 0.]

# %% [markdown]
# ### Model building:

# %%
def gradient_decent(data, target, learn_rate):
    m, n = data.shape
    w = np.zeros(n)
    temp_w = w - learn_rate*dJ_dw
    temp_b = b - learn_rate*dJ_db
    w = temp_w
    b = temp_b
# Out:
#   Cell In[69], line 1
#     def gradient_decent(data, target, learn_rate){
#                                                  ^
# SyntaxError: expected ':'
